# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnSenina/Python_for_CL/blob/main/homeworks/Hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Работа с файлами, pandas + парсинг
# Собираем корпус эко-новостей с сайта новостного издания "Ведомости"
#
# [По этой ссылке можно найти главную страницу](https://www.vedomosti.ru/ecology)
#
# Что нам предстоит сделать:
#
# достать все заголовки новостей в главной страницы + текст каждой новости
#
# сохранить в датафрейм с колонками "ссылка", "дата", "заголовок", "текст"
#
# сохранить датафрейм в файл
#
# положить код и получившийся файл в свой репозиторий на гитхабе

# %% [markdown]
# ### Способ первый, классический, как нас научили

# %%
import requests # Импортируем нужные библиотеки
from bs4 import BeautifulSoup
import pandas as pd
import re
import os

# %%
url = 'https://www.vedomosti.ru/ecology/'
page = requests.get(url) # Запрашиваем страницу

# %%
page # Проверяем, что страница вернула код 200
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, 'html') # Парсим полученную страницу супом
#print(soup.prettify()) # Смотрим на ее структуру в красивом виде

# %%
# Найдем ссылки на выпуски новостей и создадим из них список
# Пути относительные, а нам надо абсолютные. Добавим к ссылкам нужную часть ссылки  
abs_urls = []
for link in soup.find_all('a'):
    if 'release' in link.get('href'):
        abs_url = 'https://www.vedomosti.ru' + link.get('href')
        if abs_url not in abs_urls: # Добавим условие, чтобы исключить повторное добавление ссылок
            abs_urls.append(abs_url)
abs_urls # Проверим, как заполнился список
# Out:
# ['https://www.vedomosti.ru/ecology/release/2022/12/08',
#  'https://www.vedomosti.ru/ecology/release/2022/11/10',
#  'https://www.vedomosti.ru/ecology/release/2022/09/08',
#  'https://www.vedomosti.ru/ecology/release/2022/07/21']

# %% [markdown]
# #### Вариант 1, используем функцию для обработки

# %%
# Эта функция достает из страницы нужную информацию:
# дату, заголовки, ссылки, если это страница выпуска, или же только текст, если это страница новости)

def EcoSpyder(url):
    
    issue_page = requests.get(url) # Запросили страницу
    issue_soup = BeautifulSoup(issue_page.text) # Обработаем каждую страницу выпуска новостей по ссылке супом

    # Проверим, что за страница, если выпуск, то вытащим дату, ссылки, заголовки

    if 'release' in url:
        dates, titles, links = [], [], []
        
        for d in issue_soup.find_all('time'):
            dates.append(d.text)
        #dates = issue_soup.find('time').text  # Дата лежит в теге <time>. В выпуске все новости с одной датой, поэтому достаточно метода find.
        
        #date_raw = issue_soup.find('title').text # В качестве альтернативы дату можно достать регулярками из <title>
        #date = re.findall(r'[0-9]{2}\.[0-9]{2}\.[0-9]{4}', date_raw) 
    
        for k in issue_soup.find_all('a'): # Искомые заголовки и ссылки на сами тексты новостей находятся в тегах  <a>
            if k.get('data-vr-title') != None: # Название новости лежит в теге <data-vr-title>, поэтому из всех тегов <a> найдем те, где этот тег заполнен
                titles.append(k.get('data-vr-title')) 
                links.append('https://www.vedomosti.ru' + k.get('href')) # Сделаем ссылки абсолютными
    
        return dates, titles, links
   
    else: # На странице новости нам нужен только текст новости
        body = []
        
        for k in issue_soup.find_all('p', {'class': 'box-paragraph__text'}): # Текст лежит в тегах <p> с этим атрибутом 
            body.append(k.text)
            final_body = ' '.join(body) # Объединим строки в сплошной текст
        
        return final_body

# %%
dates, titles, links, news_texts = [], [], [], [] # Создадим списки ключей и значений для словаря, из которого потом сделаем фрейм

for i in range(len(abs_urls)): # Перебираем каждую ссылку на выпуск новостей
    newspiece = EcoSpyder(abs_urls[i]) # Вытаскиваем из нее нужную инфо
    
    dates.append(newspiece[0])
    titles.append(newspiece[1])
    links.append(newspiece[2])
    
#    keys.append(newspiece[0]) # Распихиваем результат по спискам: дата - в ключи, она будет индексом
#    values.append(newspiece[1:]) # Распихиваем результат по спискам: все остальное - в значения

#news_dict = {keys[x]: list(values[x]) for x in range(len(keys))} # Скомпонуем словарь
#news_dict

for l in range(len(links)): # Пройдем по словарю, по каждой дате выпуска 
    for m in range(len(links[l])): # Пройдем по каждой ссылке в каждом выпуске 
        news = EcoSpyder(links[l][m]) # Вытащим тексты
        news_texts.append(news) # Добавим их в список

#print(*dates)
#print(*links) # Посмотрим, что на выходе.
#print(*titles)
print(lenзкште(дут(туцы_еучеыб ыуз=э\т\т\тэ))news_texts, sep='\n\n\n'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [123], in <cell line: 24>()
#      19         news_texts.append(news) # Добавим их в список
#      21 #print(*dates)
#      22 #print(*links) # Посмотрим, что на выходе.
#      23 #print(*titles)
# ---> 24 print(len(news_texts, sep='\n\n\n'))
#
# TypeError: len() takes no keyword arguments

# %%
for i in range(len(dates)):
    print(dates[i])
    print(*zip(links[i], titles[i], news_texts))
# Out:
# [' 08.12.2022', ' 08.12.2022', ' 08.12.2022', ' 08.12.2022']
# ('https://www.vedomosti.ru/ecology/climate/articles/2022/12/08/954315-energetika-nulevim-sledom', 'Энергетика с нулевым следом', 'Климатическая повестка, декарбонизация, зеленая энергетика — эти понятия стали неотъемлемой частью деятельности мировых общественных организаций и ответственного бизнеса. Все крупнейшие энергетические компании, в том числе российские атомщики, основные поставщики экологически чистой электроэнергии в России, много лет ведут работу в этом направлении. На атомную энергетику приходится 20% российской генерации, а углеродный след от нее практически равен нулю. Зачем бороться с глобальным потеплением Главная цель Парижского соглашения 2015 г. в рамках конвенции ООН об изменении климата состоит в том, чтобы удержать рост глобальной температуры на уровне ниже 2 °C по сравнению с доиндустриальным уровнем и приложить усилия для ограничения повышения температуры до 1,5 °C. Это обусловлено научным консенсусом в отношении того, что ограничение роста парникового эффекта значительно снизит риски, связанные с изменением климата. Однако выбросы углекислого газа, связанные с энергетикой, продолжают расти: согласно данным Международного энергетического агентства (МЭА), в 2021 г. они выросли на 6% до 36,3 млрд т, самого высокого уровня за всю историю. Согласно заключению Межправительственной группы экспертов по изменению климата (МГЭИК) ООН, опубликованному в прошлом году, выбросы парниковых газов на нынешнем уровне приведут к нарушению климатического баланса и необратимым изменениям в окружающей среде чуть более чем через 10 лет, что говорит о необходимости практических действий по борьбе с глобальным потеплением уже сейчас. Зеленые тона атомной энергетики Два года назад Зион Лайтс, британская писательница и экоактивистка, пресс-секретарь международной экологической и антиядерной организации «Восстание против вымирания» (Extinction Rebellion), перешла на сторону развития атомной энергетики и присоединилась к международному проядерному экологическому движению «Экологический прогресс» (Environmental Progress). Свое решение она
альным потеплением уже сейчас. Зеленые тона атомной энергетики Два года назад Зион Лайтс, британская писательница и экоактивистка, пресс-секретарь международной экологической и антиядерной организации «Восстание против вымирания» (Extinction Rebellion), перешла на сторону развития атомной энергетики и присоединилась к международному проядерному экологическому движению «Экологический прогресс» (Environmental Progress). Свое решение она объяснила тем, что была подвержена антинаучным настроениям и согласилась, что использование атомной энергетики важно для сдерживания темпа глобального потепления. «Что если вы посвятили большую часть своей жизни попыткам спасти планету, — написала она в журнале Quillette, — но потом поняли, что, возможно, на самом деле усугубили ситуацию?» Этот вопрос сегодня крайне актуален для многих экологов. За последние полвека наблюдается большой прогресс в уменьшении загрязнения воздуха и воды, сохранении и защите дикой природы, но, когда речь идет о борьбе с глобальным потеплением, оказывается, что намеченные странами и компаниями планы по декарбонизации попросту не могут быть выполнены. Согласно исследованию консалтинговой компании Accenture, более трети из 2000 крупнейших государственных и частных компаний мира публично заявили о целях по нулевым выбросам, но 93% из них не могут достичь этих целей исходя из текущих социально-экономических условий. Пример такого подхода — госкорпорация «Росатом», которая за 15 лет существования стала одной из лучших генерирующих компаний с точки зрения экологии. «В Росатоме разработана экологическая стратегия, направленная на предотвращение угрозы изменения климата, которая определяет соблюдение всех необходимых стандартов в области ESG, в том числе международных», — отметил член общественного совета Росатома Валерий Меньщиков. Проблемой остается и затянувшаяся «война» против атомной энергетики, единственной технологии, демонстрирующей способность резко сократить выбросы углекислого газа в мире. «Когда случаются экологические протесты, как это было, например, не так давно при строительстве АЭС в Индии, мы проводим кропотливую и порой длительную разъяснительную работу. Это непростая задача, ведь в прошлом в мировой атомной энергетике случались катастрофы. Нам необходимо показать, что мы строим наиболее п ...

# %%
list1 = ('a','b','c')

list2 = ('1','2','3')

list3 = ('4','5','6')

list4 = ('7', '8', '9')

# %%
print(*zip(list2, list3))
# Out:
# ('1', '4') ('2', '5') ('3', '6')

# %%
dict(zip(list1, zip(list2, list3)))
# Out:
# {'a': ('1', '4'), 'b': ('2', '5'), 'c': ('3', '6')}

# %%
dict(zip(list1, zip(map(int, list2), map(int, list3))))
# Out:
# {'a': (1, 4), 'b': (2, 5), 'c': (3, 6)}

# %%
dict(zip(list1, map(list, zip(map(int, list2), map(int, list3)))))
# Out:
# {'a': [1, 4], 'b': [2, 5], 'c': [3, 6]}

# %%
dict(zip(list1, map(list, zip(*(map(int, lst) for lst in (list2, list3, list4))))))
# Out:
# {'a': [1, 4, 7], 'b': [2, 5, 8], 'c': [3, 6, 9]}

# %% [markdown]
# news_df = pd.DataFrame.from_dict(news_dict, orient="columns").T.rename(columns={0:"city", 1:"age"})

# %%
news_df = pd.DataFrame()
#news_df = pd.DataFrame(values, index=dates, columns=['title', 'link'])
display(news_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [59], in <cell line: 3>()
#       1 # Собирать датафрейм из списков??
# ----> 3 news_df = pd.DataFrame(v)
#       4 #news_df = pd.DataFrame(values, index=dates, columns=['title', 'link'])
#       5 display(news_df)
#
# NameError: name 'v' is not defined

# %%
df = pd.DataFrame.from_dict(news_dict).T
display(df)
